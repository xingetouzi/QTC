# %% [markdown]
# ## TA_LIB

# %%
import talib as ta
import numpy as np

data = np.array(range(0,10,1), dtype=np.float64)
ta.MA(data,2)
# Out:
# array([ nan,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5])

# %% [markdown]
# ## JAQS

# %%
from jaqs.data import DataView
from jaqs.data import RemoteDataService
import os
import numpy as np
import warnings

warnings.filterwarnings("ignore")

data_config = {
    "remote.data.address": "tcp://data.tushare.org:8910",
    "remote.data.username": "13662241013",
    "remote.data.password": "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MTc2NDQzMzg5MTIiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTM2NjIyNDEwMTMifQ.sVIzI5VLqq8fbZCW6yZZW0ClaCkcZpFqpiK944AHEow"
}

ds = RemoteDataService()
ds.init_from_config(data_config)
dv = DataView()

start=20180104
end=20180110

props = {'start_date': start, 'end_date': end, 'universe': '000300.SH',
         'fields': 'roe,pb,sw1',
         'freq': 1}

dv.init_from_config(props, ds)
dv.prepare_data()
dv.get_ts('roe')
# Out:
# Begin: DataApi login 13662241013@tcp://data.tushare.org:8910
#     login success
#
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# WARNING: some data is unavailable:
#     At fields
# Query data - daily fields prepared.
# Query data - quarterly fields prepared.
# Query instrument info...
# Query adj_factor...
# Query benchmark...
# Query benchmar member info...
# Query groups (industry)...
# Field [sw1] is overwritten.
# Data has been successfully prepared.
# symbol      000001.SZ  000002.SZ  000008.SZ  000009.SZ  000060.SZ  000063.SZ  \
# trade_date
# 20180104       9.1144      9.652     1.9734     3.9566     9.7856    10.2956
# 20180105       9.1144      9.652     1.9734     3.9566     9.7856    10.2956
# 20180108       9.1144      9.652     1.9734     3.9566     9.7856    10.2956
# 20180109       9.1144      9.652     1.9734     3.9566     9.7856    10.2956
# 20180110       9.1144      9.652     1.9734     3.9566     9.7856    10.2956
#
# symbol      000069.SZ  000100.SZ  000156.SZ  000157.SZ    ...      601989.SH  \
# trade_date                                                ...
# 20180104       10.317      8.049     4.6414     3.4595    ...         1.8375
# 20180105       10.317      8.049     4.6414     3.4595    ...         1.8375
# 20180108       10.317      8.049     4.6414     3.4595    ...         1.8375
# 20180109       10.317      8.049     4.6414     3.4595    ...         1.8375
# 20180110       10.317      8.049     4.6414     3.4595    ...         1.8375
#
# symbol      601991.SH  601992.SH  601997.SH  601998.SH  603160.SH  603799.SH  \
# trade_date
# 20180104       4.6901     5.7685     14.264     8.9627    25.0932    22.7842
# 20180105       4.6901     5.7685     14.264     8.9627    25.0932    22.7842
# 20180108       4.6901     5.7685     14.264     8.9627    25.0932    22.7842
# 20180109       4.6901     5.7685     14.264     8.9627    25.0932    22.7842
# 20180110       4.6901     5.7685     14.264     8.9627    25.0932    22.7842
#
# symbol      603833.SH  603858.SH  603993.SH
# trade_date
# 20180104      20.9629     8.9546     5.7288
# 20180105      20.9629     8.9546     5.7288
# 20180108      20.9629     8.9546     5.7288
# 20180109      20.9629     8.9546     5.7288
# 20180110      20.9629     8.9546     5.7288
#
# [5 rows x 324 columns]

# %%
dv.data_api.data_api.close()

# %%
dv.get_ts('pb')
# Out:
# symbol      000001.SZ  000002.SZ  000008.SZ  000009.SZ  000060.SZ  000063.SZ  \
# trade_date
# 20180104       1.1481     3.1418     3.9182     3.5312     2.7327     3.8554
# 20180105       1.1524     3.2973     3.8595     3.4896     2.7231     3.7655
# 20180108       1.1230     3.4140     3.8234     3.4758     2.7809     3.7164
# 20180109       1.1334     3.3998     3.8324     3.4573     2.7857     3.7979
# 20180110       1.1672     3.3837     3.8324     3.4111     2.7303     3.7530
#
# symbol      000069.SZ  000100.SZ  000156.SZ  000157.SZ    ...      601989.SH  \
# trade_date                                                ...
# 20180104       1.5458     1.8692     1.5942     0.9322    ...         1.8234
# 20180105       1.6278     1.8504     1.5942     0.9446    ...         1.8264
# 20180108       1.6227     1.8315     1.5942     0.9632    ...         1.8204
# 20180109       1.6244     1.9023     1.5942     0.9570    ...         1.8443
# 20180110       1.6022     1.8834     1.5942     0.9550    ...         1.8204
#
# symbol      601991.SH  601992.SH  601997.SH  601998.SH  603160.SH  603799.SH  \
# trade_date
# 20180104       1.3534     1.4223     1.3615     0.8662    13.6056    10.0646
# 20180105       1.3534     1.4315     1.3605     0.8730    13.1976    10.1946
# 20180108       1.3693     1.4362     1.3713     0.8865    13.5023    10.5567
# 20180109       1.3566     1.4037     1.3713     0.8784    13.4166    10.4199
# 20180110       1.3470     1.3875     1.3810     0.8947    13.4751    10.3470
#
# symbol      603833.SH  603858.SH  603993.SH
# trade_date
# 20180104       8.5362     2.8078     4.1891
# 20180105       8.5438     2.8116     4.1485
# 20180108       8.7167     2.8132     4.2296
# 20180109       8.7874     2.8283     4.1949
# 20180110       8.7956     2.7786     4.1775
#
# [5 rows x 324 columns]

# %%
dv.add_formula('roe_pb', 'roe/pb', is_quarterly=False).loc[start:]
# Out:
# symbol    000001.SZ  000002.SZ  000008.SZ  000009.SZ  000060.SZ  000063.SZ  \
# 20180104   7.938681   3.072124   0.503650   1.120469   3.580927   2.670436
# 20180105   7.909059   2.927244   0.511310   1.133826   3.593551   2.734192
# 20180108   8.116118   2.827182   0.516137   1.138328   3.518861   2.770315
# 20180109   8.041645   2.838991   0.514925   1.144419   3.512798   2.710867
# 20180110   7.808773   2.852499   0.514925   1.159919   3.584075   2.743299
#
# symbol    000069.SZ  000100.SZ  000156.SZ  000157.SZ    ...      601989.SH  \
# 20180104   6.674214   4.306120   2.911429   3.711113    ...       1.007733
# 20180105   6.338002   4.349870   2.911429   3.662397    ...       1.006078
# 20180108   6.357922   4.394758   2.911429   3.591674    ...       1.009394
# 20180109   6.351268   4.231194   2.911429   3.614943    ...       0.996313
# 20180110   6.439271   4.273654   2.911429   3.622513    ...       1.009394
#
# symbol    601991.SH  601992.SH  601997.SH  601998.SH  603160.SH  603799.SH  \
# 20180104   3.465420   4.055755  10.476680  10.347148   1.844329   2.263796
# 20180105   3.465420   4.029689  10.484381  10.266552   1.901346   2.234928
# 20180108   3.425181   4.016502  10.401809  10.110209   1.858439   2.158269
# 20180109   3.457246   4.109496  10.401809  10.203438   1.870310   2.186604
# 20180110   3.481886   4.157477  10.328747  10.017548   1.862190   2.202010
#
# symbol    603833.SH  603858.SH  603993.SH
# 20180104   2.455765   3.189187   1.367549
# 20180105   2.453580   3.184877   1.380933
# 20180108   2.404912   3.183066   1.354454
# 20180109   2.385563   3.166071   1.365658
# 20180110   2.383339   3.222702   1.371346
#
# [5 rows x 324 columns]

# %% [markdown]
# ## Rqalpha

# %%
import rqalpha
from rqalpha.api import *
import talib
import pandas as pd


def init(context):
    context.s1 = "000001.XSHE"
    context.SHORTPERIOD = 3
    context.LONGPERIOD = 5

def handle_bar(context, bar_dict):
    prices = history_bars(context.s1, context.LONGPERIOD+1, '1d', 'close')
    short_avg = talib.SMA(prices, context.SHORTPERIOD)
    long_avg = talib.SMA(prices, context.LONGPERIOD)

    # 计算现在portfolio中股票的仓位
    cur_position = context.portfolio.positions[context.s1].quantity
    avg_price = context.portfolio.positions[context.s1].avg_price
    capital = cur_position*avg_price
    # 计算现在portfolio中的现金可以购买多少股票
    shares = context.portfolio.cash/bar_dict[context.s1].close
    #图形显示当前占用资金
    plot('capital', capital)

    # 如果短均线从上往下跌破长均线，而上一个bar的短线平均值高于长线平均值
    if short_avg[-1] - long_avg[-1] < 0 and short_avg[-2] - long_avg[-2] > 0 and cur_position > 0:
        # 进行清仓
        order_target_value(context.s1, 0)

    # 如果短均线从下往上突破长均线，为入场信号
    if short_avg[-1] - long_avg[-1] > 0 and short_avg[-2] - long_avg[-2] < 0:
        # 满仓入股
        order_shares(context.s1, shares)

config = {
  "base": {
    "start_date": "2018-01-04",
    "end_date": "2018-03-04",
    "accounts": {'stock':1000000},
    "benchmark": "000001.XSHE",
  },
  "extra": {
    "log_level": "error",
  },
  "mod": {
    "sys_analyser": {
      "enabled": True,
      "plot": True
    }
  }
}

# 您可以指定您要传递的参数
rqalpha.run_func(init=init, handle_bar=handle_bar, config=config)
# Out:
# WARNING: better_exceptions will only inspect code from the command line
#          when using: `python -m better_exceptions'. Otherwise, only code
#          loaded from files will be inspected!
# {'sys_analyser': {'benchmark_portfolio':             cash  market_value  static_unit_net_value  total_value  \
#   date
#   2018-01-04  9.25     999990.75                  1.000   1000000.00
#   2018-01-05  9.25    1003764.30                  1.000   1003773.55
#   2018-01-08  9.25     978104.16                  1.004    978113.41
#   2018-01-09  9.25     987160.68                  0.978    987169.93
#   2018-01-10  9.25    1016594.37                  0.987   1016603.62
#   2018-01-11  9.25    1011311.40                  1.017   1011320.65
#   2018-01-12  9.25    1022632.05                  1.011   1022641.30
#   2018-01-15  9.25    1071688.20                  1.023   1071697.45
#   2018-01-16  9.25    1071688.20                  1.072   1071697.45
#   2018-01-17  9.25    1073952.33                  1.072   1073961.58
#   2018-01-18  9.25    1110933.12                  1.074   1110942.37
#   2018-01-19  9.25    1116970.80                  1.111   1116980.05
#   2018-01-22  9.25    1089801.24                  1.117   1089810.49
#   2018-01-23  9.25    1105650.15                  1.090   1105659.40
#   2018-01-24  9.25    1104895.44                  1.106   1104904.69
#   2018-01-25  9.25    1071688.20                  1.105   1071697.45
#   2018-01-26  9.25    1060367.55                  1.072   1060376.80
#   2018-01-29  9.25    1036971.54                  1.060   1036980.79
#   2018-01-30  9.25    1030179.15                  1.037   1030188.40
#   2018-01-31  9.25    1060367.55                  1.030   1060376.80
#   2018-02-01  9.25    1058858.13                  1.060   1058867.38
#   2018-02-02  9.25    1060367.55                  1.059   1060376.80
#   2018-02-05  9.25    1098103.05                  1.060   1098112.30
#   2018-02-06  9.25    1056594.00                  1.098   1056603.25
#   2018-02-07  9.25     975085.32                  1.057    975094.57
#   2018-02-08  9.25     946406.34                  0.975    946415.59
#   2018-02-09  9.25     882255.99                  0.946    882265.24
#   2018-02-12  9.25     884520.12                  0.882    884529.37
#   2018-02-13  9.25     901123.74                  0.885    901132.99
#   2018-02-14  9.25     905652.00                  0.901    905661.25
#   2018-02-22  9.25     940368.66                  0.906    940377.91
#   2018-02-23  9.25     951689.31                  0.940    951698.56
#   2018-02-26  9.25     953198.73                  0.952    953207.98
#   2018-02-27  9.25     926783.88                  0.953    926793.13
#   2018-02-28  9.25     909425.55                  0.927    909434.80
#   2018-03-01  9.25     908670.84                  0.909    908680.09
#   2018-03-02  9.25     901878.45                  0.909    901887.70
#
#               unit_net_value      units
#   date
#   2018-01-04        1.000000  1000000.0
#   2018-01-05        1.003774  1000000.0
#   2018-01-08        0.978113  1000000.0
#   2018-01-09        0.987170  1000000.0
#   2018-01-10        1.016604  1000000.0
#   2018-01-11        1.011321  1000000.0
#   2018-01-12        1.022641  1000000.0
#   2018-01-15        1.071697  1000000.0
#   2018-01-16        1.071697  1000000.0
#   2018-01-17        1.073962  1000000.0
#   2018-01-18        1.110942  1000000.0
#   2018-01-19        1.116980  1000000.0
#   2018-01-22        1.089810  1000000.0
#   2018-01-23        1.105659  1000000.0
#   2018-01-24        1.104905  1000000.0
#   2018-01-25        1.071697  1000000.0
#   2018-01-26        1.060377  1000000.0
#   2018-01-29        1.036981  1000000.0
#   2018-01-30        1.030188  1000000.0
#   2018-01-31        1.060377  1000000.0
#   2018-02-01        1.058867  1000000.0
#   2018-02-02        1.060377  1000000.0
#   2018-02-05        1.098112  1000000.0
#   2018-02-06        1.056603  1000000.0
#   2018-02-07        0.975095  1000000.0
#   2018-02-08        0.946416  1000000.0
#   2018-02-09        0.882265  1000000.0
#   2018-02-12        0.884529  1000000.0
#   2018-02-13        0.901133  1000000.0
#   2018-02-14        0.905661  1000000.0
#   2018-02-22        0.940378  1000000.0
#   2018-02-23        0.951699  1000000.0
#   2018-02-26        0.953208  1000000.0
#   2018-02-27        0.926793  1000000.0
#   2018-02-28        0.909435  1000000.0
#   2018-03-01        0.908680  1000000.0
#   2018-03-02        0.901888  1000000.0  , 'plots':               capital
#   date
#   2018-01-04        0.0
#   2018-01-05        0.0
#   2018-01-08        0.0
#   2018-01-09        0.0
#   2018-01-10        0.0
#   2018-01-11        0.0
#   2018-01-12   999640.0
#   2018-01-15   999640.0
#   2018-01-16   999640.0
#   2018-01-17   999640.0
#   2018-01-18   999640.0
#   2018-01-19   999640.0
#   2018-01-22   999640.0
#   2018-01-23   999640.0
#   2018-01-24   999640.0
#   2018-01-25        0.0
#   2018-01-26        0.0
#   2018-01-29        0.0
#   2018-01-30        0.0
#   2018-01-31        0.0
#   2018-02-01        0.0
#   2018-02-02  1088728.0
#   2018-02-05  1088728.0
#   2018-02-06  1088728.0
#   2018-02-07  1088728.0
#   2018-02-08        0.0
#   2018-02-09        0.0
#   2018-02-12        0.0
#   2018-02-13        0.0
#   2018-02-14        0.0
#   2018-02-22        0.0
#   2018-02-23  1000538.0
#   2018-02-26  1000538.0
#   2018-02-27  1000538.0
#   2018-02-28  1000538.0
#   2018-03-01        0.0
#   2018-03-02        0.0, 'portfolio':                    cash  market_value  static_unit_net_value  total_value  \
#   date
#   2018-01-04  1000000.000           0.0                  1.000  1000000.000
#   2018-01-05  1000000.000           0.0                  1.000  1000000.000
#   2018-01-08  1000000.000           0.0                  1.000  1000000.000
#   2018-01-09  1000000.000           0.0                  1.000  1000000.000
#   2018-01-10  1000000.000           0.0                  1.000  1000000.000
#   2018-01-11     -439.712      999640.0                  1.000   999200.288
#   2018-01-12     -439.712     1010830.0                  0.999  1010390.288
#   2018-01-15     -439.712     1059320.0                  1.010  1058880.288
#   2018-01-16     -439.712     1059320.0                  1.059  1058880.288
#   2018-01-17     -439.712     1061558.0                  1.059  1061118.288
#   2018-01-18     -439.712     1098112.0                  1.061  1097672.288
#   2018-01-19     -439.712     1104080.0                  1.098  1103640.288
#   2018-01-22     -439.712     1077224.0                  1.104  1076784.288
#   2018-01-23     -439.712     1092890.0                  1.077  1092450.288
#   2018-01-24  1089738.429           0.0                  1.092  1089738.429
#   2018-01-25  1089738.429           0.0                  1.090  1089738.429
#   2018-01-26  1089738.429           0.0                  1.090  1089738.429
#   2018-01-29  1089738.429           0.0                  1.090  1089738.429
#   2018-01-30  1089738.429           0.0                  1.090  1089738.429
#   2018-01-31  1089738.429           0.0                  1.090  1089738.429
#   2018-02-01      139.446     1088728.0                  1.090  1088867.446
#   2018-02-02      139.446     1090280.0                  1.089  1090419.446
#   2018-02-05      139.446     1129080.0                  1.090  1129219.446
#   2018-02-06      139.446     1086400.0                  1.129  1086539.446
#   2018-02-07  1000926.781           0.0                  1.087  1000926.781
#   2018-02-08  1000926.781           0.0                  1.001  1000926.781
#   2018-02-09  1000926.781           0.0                  1.001  1000926.781
#   2018-02-12  1000926.781           0.0                  1.001  1000926.781
#   2018-02-13  1000926.781           0.0                  1.001  1000926.781
#   2018-02-14  1000926.781           0.0                  1.001  1000926.781
#   2018-02-22     -411.650     1000538.0                  1.001  1000126.350
#   2018-02-23     -411.650     1012583.0                  1.000  1012171.350
#   2018-02-26     -411.650     1014189.0                  1.012  1013777.350
#   2018-02-27     -411.650      986084.0                  1.014   985672.350
#   2018-02-28   965461.643           0.0                  0.986   965461.643
#   2018-03-01   965461.643           0.0                  0.965   965461.643
#   2018-03-02   965461.643           0.0                  0.965   965461.643
#
#               unit_net_value      units
#   date
#   2018-01-04        1.000000  1000000.0
#   2018-01-05        1.000000  1000000.0
#   2018-01-08        1.000000  1000000.0
#   2018-01-09        1.000000  1000000.0
#   2018-01-10        1.000000  1000000.0
#   2018-01-11        0.999200  1000000.0
#   2018-01-12        1.010390  1000000.0
#   2018-01-15        1.058880  1000000.0
#   2018-01-16        1.058880  1000000.0
#   2018-01-17        1.061118  1000000.0
#   2018-01-18        1.097672  1000000.0
#   2018-01-19        1.103640  1000000.0
#   2018-01-22        1.076784  1000000.0
#   2018-01-23        1.092450  1000000.0
#   2018-01-24        1.089738  1000000.0
#   2018-01-25        1.089738  1000000.0
#   2018-01-26        1.089738  1000000.0
#   2018-01-29        1.089738  1000000.0
#   2018-01-30        1.089738  1000000.0
#   2018-01-31        1.089738  1000000.0
#   2018-02-01        1.088867  1000000.0
#   2018-02-02        1.090419  1000000.0
#   2018-02-05        1.129219  1000000.0
#   2018-02-06        1.086539  1000000.0
#   2018-02-07        1.000927  1000000.0
#   2018-02-08        1.000927  1000000.0
#   2018-02-09        1.000927  1000000.0
#   2018-02-12        1.000927  1000000.0
#   2018-02-13        1.000927  1000000.0
#   2018-02-14        1.000927  1000000.0
#   2018-02-22        1.000126  1000000.0
#   2018-02-23        1.012171  1000000.0
#   2018-02-26        1.013777  1000000.0
#   2018-02-27        0.985672  1000000.0
#   2018-02-28        0.965462  1000000.0
#   2018-03-01        0.965462  1000000.0
#   2018-03-02        0.965462  1000000.0  , 'stock_account':                    cash  dividend_receivable  market_value  total_value  \
#   date
#   2018-01-04  1000000.000                    0           0.0  1000000.000
#   2018-01-05  1000000.000                    0           0.0  1000000.000
#   2018-01-08  1000000.000                    0           0.0  1000000.000
#   2018-01-09  1000000.000                    0           0.0  1000000.000
#   2018-01-10  1000000.000                    0           0.0  1000000.000
#   2018-01-11     -439.712                    0      999640.0   999200.288
#   2018-01-12     -439.712                    0     1010830.0  1010390.288
#   2018-01-15     -439.712                    0     1059320.0  1058880.288
#   2018-01-16     -439.712                    0     1059320.0  1058880.288
#   2018-01-17     -439.712                    0     1061558.0  1061118.288
#   2018-01-18     -439.712                    0     1098112.0  1097672.288
#   2018-01-19     -439.712                    0     1104080.0  1103640.288
#   2018-01-22     -439.712                    0     1077224.0  1076784.288
#   2018-01-23     -439.712                    0     1092890.0  1092450.288
#   2018-01-24  1089738.429                    0           0.0  1089738.429
#   2018-01-25  1089738.429                    0           0.0  1089738.429
#   2018-01-26  1089738.429                    0           0.0  1089738.429
#   2018-01-29  1089738.429                    0           0.0  1089738.429
#   2018-01-30  1089738.429                    0           0.0  1089738.429
#   2018-01-31  1089738.429                    0           0.0  1089738.429
#   2018-02-01      139.446                    0     1088728.0  1088867.446
#   2018-02-02      139.446                    0     1090280.0  1090419.446
#   2018-02-05      139.446                    0     1129080.0  1129219.446
#   2018-02-06      139.446                    0     1086400.0  1086539.446
#   2018-02-07  1000926.781                    0           0.0  1000926.781
#   2018-02-08  1000926.781                    0           0.0  1000926.781
#   2018-02-09  1000926.781                    0           0.0  1000926.781
#   2018-02-12  1000926.781                    0           0.0  1000926.781
#   2018-02-13  1000926.781                    0           0.0  1000926.781
#   2018-02-14  1000926.781                    0           0.0  1000926.781
#   2018-02-22     -411.650                    0     1000538.0  1000126.350
#   2018-02-23     -411.650                    0     1012583.0  1012171.350
#   2018-02-26     -411.650                    0     1014189.0  1013777.350
#   2018-02-27     -411.650                    0      986084.0   985672.350
#   2018-02-28   965461.643                    0           0.0   965461.643
#   2018-03-01   965461.643                    0           0.0   965461.643
#   2018-03-02   965461.643                    0           0.0   965461.643
#
#               transaction_cost
#   date
#   2018-01-04             0.000
#   2018-01-05             0.000
#   2018-01-08             0.000
#   2018-01-09             0.000
#   2018-01-10             0.000
#   2018-01-11           799.712
#   2018-01-12             0.000
#   2018-01-15             0.000
#   2018-01-16             0.000
#   2018-01-17             0.000
#   2018-01-18             0.000
#   2018-01-19             0.000
#   2018-01-22             0.000
#   2018-01-23             0.000
#   2018-01-24          1965.859
#   2018-01-25             0.000
#   2018-01-26             0.000
#   2018-01-29             0.000
#   2018-01-30             0.000
#   2018-01-31             0.000
#   2018-02-01           870.982
#   2018-02-02             0.000
#   2018-02-05             0.000
#   2018-02-06             0.000
#   2018-02-07          1804.666
#   2018-02-08             0.000
#   2018-02-09             0.000
#   2018-02-12             0.000
#   2018-02-13             0.000
#   2018-02-14             0.000
#   2018-02-22           800.430
#   2018-02-23             0.000
#   2018-02-26             0.000
#   2018-02-27             0.000
#   2018-02-28          1741.707
#   2018-03-01             0.000
#   2018-03-02             0.000  , 'stock_positions':             avg_price  last_price  market_value order_book_id  quantity symbol
#   date
#   2018-01-11      13.40       13.40      999640.0   000001.XSHE     74600   平安银行
#   2018-01-12      13.40       13.55     1010830.0   000001.XSHE     74600   平安银行
#   2018-01-15      13.40       14.20     1059320.0   000001.XSHE     74600   平安银行
#   2018-01-16      13.40       14.20     1059320.0   000001.XSHE     74600   平安银行
#   2018-01-17      13.40       14.23     1061558.0   000001.XSHE     74600   平安银行
#   2018-01-18      13.40       14.72     1098112.0   000001.XSHE     74600   平安银行
#   2018-01-19      13.40       14.80     1104080.0   000001.XSHE     74600   平安银行
#   2018-01-22      13.40       14.44     1077224.0   000001.XSHE     74600   平安银行
#   2018-01-23      13.40       14.65     1092890.0   000001.XSHE     74600   平安银行
#   2018-01-24      13.40       14.64           0.0   000001.XSHE         0   平安银行
#   2018-02-01      14.03       14.03     1088728.0   000001.XSHE     77600   平安银行
#   2018-02-02      14.03       14.05     1090280.0   000001.XSHE     77600   平安银行
#   2018-02-05      14.03       14.55     1129080.0   000001.XSHE     77600   平安银行
#   2018-02-06      14.03       14.00     1086400.0   000001.XSHE     77600   平安银行
#   2018-02-07      14.03       12.92           0.0   000001.XSHE         0   平安银行
#   2018-02-22      12.46       12.46     1000538.0   000001.XSHE     80300   平安银行
#   2018-02-23      12.46       12.61     1012583.0   000001.XSHE     80300   平安银行
#   2018-02-26      12.46       12.63     1014189.0   000001.XSHE     80300   平安银行
#   2018-02-27      12.46       12.28      986084.0   000001.XSHE     80300   平安银行
#   2018-02-28      12.46       12.05           0.0   000001.XSHE         0   平安银行, 'summary': {'STOCK': 1000000.0,
#    'alpha': 0.13900000000000001,
#    'annualized_returns': -0.19800000000000001,
#    'benchmark': '000001.XSHE',
#    'benchmark_annualized_returns': -0.47799999999999998,
#    'benchmark_total_returns': -0.098000000000000004,
#    'beta': 0.56399999999999995,
#    'cash': 965461.64300000004,
#    'downside_risk': 0.16,
#    'end_date': '2018-03-02',
#    'information_ratio': 1.482,
#    'max_drawdown': 0.14499999999999999,
#    'run_type': 'BACKTEST',
#    'sharpe': -0.68200000000000005,
#    'sortino': -1.3460000000000001,
#    'start_date': '2018-01-04',
#    'strategy_file': 'strategy.py',
#    'strategy_name': 'strategy',
#    'total_returns': -0.035000000000000003,
#    'total_value': 965461.64300000004,
#    'tracking_error': 0.27800000000000002,
#    'unit_net_value': 0.96499999999999997,
#    'units': 1000000.0,
#    'volatility': 0.315}, 'trades':                      commission     exec_id  last_price  last_quantity  \
#   datetime
#   2018-01-11 15:00:00    799.7120  1521100286       13.40          74600
#   2018-01-24 15:00:00    873.7152  1521100287       14.64          74600
#   2018-02-01 15:00:00    870.9824  1521100288       14.03          77600
#   2018-02-07 15:00:00    802.0736  1521100289       12.92          77600
#   2018-02-22 15:00:00    800.4304  1521100290       12.46          80300
#   2018-02-28 15:00:00    774.0920  1521100291       12.05          80300
#
#                       order_book_id    order_id position_effect  side symbol  \
#   datetime
#   2018-01-11 15:00:00   000001.XSHE  1521100285            None   BUY   平安银行
#   2018-01-24 15:00:00   000001.XSHE  1521100286            None  SELL   平安银行
#   2018-02-01 15:00:00   000001.XSHE  1521100287            None   BUY   平安银行
#   2018-02-07 15:00:00   000001.XSHE  1521100288            None  SELL   平安银行
#   2018-02-22 15:00:00   000001.XSHE  1521100289            None   BUY   平安银行
#   2018-02-28 15:00:00   000001.XSHE  1521100290            None  SELL   平安银行
#
#                             tax     trading_datetime  transaction_cost
#   datetime
#   2018-01-11 15:00:00     0.000  2018-01-11 15:00:00          799.7120
#   2018-01-24 15:00:00  1092.144  2018-01-24 15:00:00         1965.8592
#   2018-02-01 15:00:00     0.000  2018-02-01 15:00:00          870.9824
#   2018-02-07 15:00:00  1002.592  2018-02-07 15:00:00         1804.6656
#   2018-02-22 15:00:00     0.000  2018-02-22 15:00:00          800.4304
#   2018-02-28 15:00:00   967.615  2018-02-28 15:00:00         1741.7070  }}
