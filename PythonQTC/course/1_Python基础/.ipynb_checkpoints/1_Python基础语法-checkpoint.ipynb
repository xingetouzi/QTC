# %% [markdown]
# ## Python基础语法

# %% [markdown]
# # I.

# %% [markdown]
# ### 交互式:
#
# 命令逐条运行
#
# 交互式编程不需要创建脚本文件，是通过 Python 解释器的交互模式进来编写代码。

# %%
>>> 1+1
# Out:
# 2

# %%
>>> a=1
>>> b=1
>>> a+b
# Out:
# 2

# %% [markdown]
# ### 脚本式:
#
# 一次性全部运行
#
# 通过脚本参数调用解释器开始执行脚本，直到脚本执行完毕。当脚本执行完成后，解释器不再有效。

# %%
my_dream='I want to be a quantitative trader.'
print('Hello,world!!! '+my_dream)
print (my_dream + ' What can I do?')
#点击run,显示运行结果:
# Out:
# Hello,world!!! I want to be a quantitative trader.
# I want to be a quantitative trader. What can I do?

# %% [markdown]
# # II.

# %% [markdown]
# ### 变量名
# 变量名为字符开头，其他可以是下划线数字字母。注意不要用到Python内建函数命名。

# %%
1I = a
# Out:
#   File "<ipython-input-4-ad871c211e7c>", line 1
#     1I = a
#      ^
# SyntaxError: invalid syntax

# %%
list = [1,2,3,4,5]

# %%
t = tuple(list)

# %%
t
# Out:
# (1, 2, 3, 4, 5)

# %%
list(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-f57fd3c9bd0b> in <module>()
# ----> 1 list(t)
#
# TypeError: 'list' object is not callable

# %% [markdown]
# # III.

# %% [markdown]
# ### 代码缩进:
#
# 缩进替代({})
#
# 学习Python与其他语言最大的区别就是，Python的代码块不使用大括号（{}）来控制类，函数以及其他逻辑判断。
# python最具特色的就是用缩进来写模块。

# %% [markdown]
# ### 代码缩进（错误）

# %%
price = 1
if price>0:
    print ('True')
        print ('price is greater than 0')
        # 没有严格缩进，在执行时会报错
else:
    print ("False")
# Out:
#   File "<ipython-input-9-95ffcc1a2fae>", line 4
#     print ('price is greater than 0')
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### 代码缩进（正确）

# %%
price = 1
if price>0:
    print ('True')
    print ('price is greater than 0')
else:
    print ("False")
# Out:
# True
# price is greater than 0

# %% [markdown]
# ### 注释代码
#
# 单行注释用 # 开头
#
# 多行注释用三个引号(''')

# %% [markdown]
# # 多行注释的用处

# %%
### 世界你好
print('hello world')
# Out:
# hello world

# %%
### 世界你好
# print('hello world')

# %%
print('now printing a quote ".')
# Out:
# now printing a quote ".

# %%
print('now printing a quote '.')
# Out:
#   File "<ipython-input-14-c671305daa5d>", line 1
#     print('now printing a quote '.')
#                                     ^
# SyntaxError: EOL while scanning string literal

# %%
print('now printing a quote \'.')
# Out:
# now printing a quote '.

# %%
print('\t now printing a quote.')
# Out:
# 	 now printing a quote.

# %%
print('''now printing a quote '.''')
# Out:
# now printing a quote '.

# %%
"""
世界你好
print('hello world')
print('all in')
"""

print("""
世界你好
print('hello world')
print('all in')
""")
# Out:
# 世界你好
# print('hello world')
# print('all in')

# %%
print(repr("""
世界你好
print('hello world')
print('all in')
"""))
# Out:
# "\n世界你好\nprint('hello world')\nprint('all in')\n"

# %% [markdown]
# ## 文件处理
# open()/write()/read()/close()
#
# os.rename()/os.remove()

# %%
who = open("channel.txt", "w")

# %%
who.write("www.fxdayu.com!\nVery good site!\n")
# Out:
# 32

# %%
who.close()

# %%
who = open("channel.txt", "r+")

# %%
channel = who.read(50)

# %%
channel
# Out:
# 'www.fxdayu.com!\nVery good site!\n'

# %%
who.close()

# %%
import os
os.rename('channel.txt', 'website.txt')

# %%
os.remove('website.txt')
